# %%
#Algoritmo para determinar si un número es par o impar python
n = int(input("Ingresa un número: "))
if n % 2 == 0:
    print("El número ",n," es par")
else:
    print("El número ",n," es impar")

# %%
#Realice un programa que lea tres números reales y determine si la suma de los dos primeros es mayor, menor o igual que el tercer número.

a = int(input("Introduce el primer número: "))
b = int(input("Introduce el segundo número: "))        
c = int(input("Introduce el terce número: "))
if (a+b)>c:
    print("La suma es mayor al tercer número")
else:
    print("El tercer número es mayor que la suma")

# %%
import math

# Función para calcular el promedio
def calcular_promedio(numeros):
    return sum(numeros) / len(numeros)

# Función para calcular la mediana
def calcular_mediana(numeros):
    numeros_ordenados = sorted(numeros)
    n = len(numeros)
    if n % 2 == 0:
        medio1 = numeros_ordenados[n // 2 - 1]
        medio2 = numeros_ordenados[n // 2]
        mediana = (medio1 + medio2) / 2
    else:
        mediana = numeros_ordenados[n // 2]
    return mediana

# Función para calcular el promedio multiplicativo
def calcular_promedio_multiplicativo(numeros):
    producto = 1
    for numero in numeros:
        producto *= numero
    return producto ** (1 / len(numeros))

# Función para ordenar números de forma ascendente y descendente
def ordenar_numeros(numeros, ascendente=True):
    return sorted(numeros) if ascendente else sorted(numeros, reverse=True)

# Función para calcular la potencia del mayor número elevado al menor número
def calcular_potencia_mayor_menor(numeros):
    mayor = max(numeros)
    menor = min(numeros)
    return mayor ** menor

# Función para calcular la raíz cúbica del menor número
def calcular_raiz_cubica_menor(numeros):
    menor = min(numeros)
    return math.pow(menor, 1/3)

# Pedir 5 números reales
numeros = []
for i in range(5):
    numero = float(input(f'Ingrese el número {i + 1}: '))
    numeros.append(numero)

# Calcular y mostrar los resultados
print(f'Promedio: {calcular_promedio(numeros)}')
print(f'Mediana: {calcular_mediana(numeros)}')
print(f'Promedio multiplicativo: {calcular_promedio_multiplicativo(numeros)}')
print(f'Números ordenados de forma ascendente: {ordenar_numeros(numeros)}')
print(f'Números ordenados de forma descendente: {ordenar_numeros(numeros, ascendente=False)}')
print(f'Potencia del mayor número elevado al menor número: {calcular_potencia_mayor_menor(numeros)}')
print(f'Raíz cúbica del menor número: {calcular_raiz_cubica_menor(numeros)}')

# %%
#Diccionario de países y sus capitales en América
paises_y_capitales_de_america = {
    "canadá": "otawwa",
    "estados unidos": "washington",
    "méxico": "méxico D.F",
    "belice": "belmopán",
    "costa rica": "san josé",
    "el salvador": "san salvador",
    "guatemala": "ciudad de Guatemala",
    "honduras": "tegucigalpa",
    "nicaragua": "managua",
    "panamá": "ciudad de panamá",
    "argentina": "buenos aires",
    "bolivia": "sucre",
    "brasil": "brasilia",
    "chile": "santiago de chile",
    "colombia": "bogotá",
    "ecuador": "quito",
    "paraguay": "asunción",
    "perú": "lima",
    "surinam": "parabarimo",
    "trinidad y tobago": "puerto españa",
    "uruguay": "montevideo",
    "venezuela": "caracas",
    "antigua y barbuda": "saint john",
    "bahamas": "nasaú",
    "barbados": "bridgetown",
    "cuba": "la habana",
    "dominica": "roseau",
    "granada": "saint george",
    "guyana": "georgetown",
    "haití": "puerto príncipe",
    "jamaica": "kingston",
    "republica dominicana": "santo Domingo",
    "san cristobal y nieves": "basseterre",
    "san vicente y granadinas": "Kingstown",
    "santa Lucía": "castries"
}


##función para obtener una capital de América
def obtener_capital_americas(pais):
    pais = pais.lower()
    if pais in paises_y_capitales_de_america:
        return paises_y_capitales_de_america[pais]
    else:
        return "pais no identificado"
    
##solicitar al usuario el nombre del país en minúsculas
nombre_pais = input("ingrese el nombre del país en minúsculas: ")

##obtener y mostrar la capital del país si pertenece a América
capital = obtener_capital_americas(nombre_pais)
if capital != "pais no identificado":
    print(f"La capital de {nombre_pais.capitalize()} en América es {capital}.")
else:
    print("país no identificado")
